# %% [markdown]
# # Stream-based Active Learning with CapyMOA

# %% [markdown]
# > **_Google Colab Note:_** If the notebook fails to run after installing the needed packages, try to restart the runtime (Ctrl + M) under Runtime -> Restart session.
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](<colab_link>)

# %% [markdown]
# **Notebook Dependencies**
#
# Uncomment the following cells to install all dependencies for this tutorial.

# %%
# !pip install scikit-activeml capymoa

# %% [markdown]
# <hr style="border-style: solid; border-top: 1px solid; border-right: 0; border-bottom: 0; border-left: 0;">

# %% [markdown]
# In this notebook, we will show how stream-based active learning strategies are used and compared them to one another. We showcase compatibility between the the methods available in the `skactiveml` stream package and the `capymoa` library.

# %%
import numpy as np
from collections import deque
from sklearn.datasets import make_blobs
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d
from skactiveml.classifier import CapyMOAClassifier
from skactiveml.stream import StreamRandomSampling, PeriodicSampling
from skactiveml.stream import (
    FixedUncertainty,
    VariableUncertainty,
    RandomVariableUncertainty,
    Split,
    StreamProbabilisticAL,
    StreamDensityBasedAL,
    CognitiveDualQueryStrategyRan,
    CognitiveDualQueryStrategyFixUn,
    CognitiveDualQueryStrategyRanVarUn,
    CognitiveDualQueryStrategyVarUn,
)
from skactiveml.utils import call_func
from capymoa.classifier import AdaptiveRandomForestClassifier

from tqdm import tqdm
import warnings

mpl.rcParams["figure.facecolor"] = "white"
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Initialize Stream Parameters
# Before the experiments can start, we need to construct an artificial data set. For this, we specify the necessary parameters in the cell below. We specify the length of the data stream `stream_length` and the size of the sliding window that defines the available training data `training_size`. Additionally we define a parameter `fit_clf` to decide if `X` and `y` are needed and should be used.

# %%
# number of samples that are provided to the classifier
init_train_length = 10
# the length of the data stream
stream_length = 5000
# the parameter dedicated to decide if the classifier needs to be refited with
# X and y.
fit_clf = False

# %% [markdown]
# ## Random Seed Generation
# To make the experiments repeatable, we will use the `random_state` object to generate all other random seeds, such that we only need to explicitly specify a single random seed. The `get_randomseed` function simplifies the generation of a new random seed using the `random_state` object.

# %%
# random state that is used to generate random seeds
random_state = np.random.RandomState(0)

def get_randomseed(random_state):
    return random_state.randint(2**31 - 1)

# %% [markdown]
# ## Generate and Initialize Data Set
# The next block initializes the tested data set. We use `scikit-learn` to generate a random data set with our pre-defined stream length. The data set consists of multiple parts. `X` represents the location of the sample within the feature space. The class for each sample is denoted by `y`.
# For models that need at least some initial training data, we generate samples to train an initial model. These are denoted by the suffix "_init", while all data used within the active learning cycle are denoted by the suffix "_stream". For this notebook we evaluate the performance of each query strategy using Prequential Evaluation. If a hold-out test data set is used, it should be initialized here as well.

# %%
X, y_centers = make_blobs(
    n_samples=init_train_length + stream_length,
    centers=30,
    random_state=get_randomseed(random_state),
    cluster_std=0.5,
    shuffle=True,
)
y = y_centers % 4
X_init = X[:init_train_length, :]
y_init = y[:init_train_length]
X_stream = X[init_train_length:, :]
y_stream = y[init_train_length:]

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Data set")
plt.show()

# %% [markdown]
# ## Initialize Query Strategies
# Next, we initialize the classifier and the base query strategies that we want to compare. To use the classifier we first need to convert the `CapyMOA` classifier to an `sklearn` classifier by using the `CapyMOAClassifier` wrapper. To guarantee that the classifier is not affected by previous repetitions, we use factory functions to separate the classifier for each experiment run. Since all query strategies have a default budget managager we use that for the sake of simplicity.

# %%
classes = np.unique(y)
clf_factory = lambda: CapyMOAClassifier(
    estimator_class=AdaptiveRandomForestClassifier,
    random_state=get_randomseed(random_state),
    classes=classes,
)
query_strategies = {
    "StreamRandomSampling": StreamRandomSampling(
        random_state=get_randomseed(random_state)
    ),
    "PeriodicSampler": PeriodicSampling(
        random_state=get_randomseed(random_state)
    ),
    "FixedUncertainty": FixedUncertainty(
        classes=classes, random_state=get_randomseed(random_state)
    ),
    "VariableUncertainty": VariableUncertainty(
        random_state=get_randomseed(random_state)
    ),
    "RandomVariableUncertainty": RandomVariableUncertainty(
        random_state=get_randomseed(random_state)
    ),
    "Split": Split(random_state=get_randomseed(random_state)),
    "DBALStream": StreamDensityBasedAL(
        random_state=get_randomseed(random_state)
    ),
    "CogDQSRan": CognitiveDualQueryStrategyRan(
        random_state=get_randomseed(random_state),
    ),
    "CogDQSFixUn": CognitiveDualQueryStrategyFixUn(
        classes=classes,
        random_state=get_randomseed(random_state),
    ),
    "CogDQSVarUn": CognitiveDualQueryStrategyVarUn(
        random_state=get_randomseed(random_state),
    ),
    "CogDQSRanVarUn": CognitiveDualQueryStrategyRanVarUn(
        random_state=get_randomseed(random_state),
    ),
    "StreamProbabilisticAL": StreamProbabilisticAL(
        random_state=get_randomseed(random_state), metric="rbf"
    ),
}

# %% [markdown]
# ## Start Active Learning Cycle
# After all, variables are initialized, we can start the experiment. The experiment loop below goes through all query strategies defined in query_strategies. For each experiment run, the average accuracy of the selected query strategies will be displayed. Lastly, the accuracy over time will be plotted.

# %%
results = {}
for iter_list in enumerate(query_strategies.items()):
    i_qs, (query_strategy_name, query_strategy) = iter_list
    clf = clf_factory()
    # save X and y using a sliding window
    # X_train and y_train are only used for the kernel density
    # estimation in StreamProbabilisticAL
    X_train = deque(maxlen=1000)
    X_train.extend(X_init)
    y_train = deque(maxlen=1000)
    y_train.extend(y_init)
    # train the model with the initially available data
    clf.fit(X_init, y_init)
    # initialize the list that stores the result of the classifier's prediction
    correct_classifications = []
    queries_t = []
    print(query_strategy_name)
    for t in tqdm(range(len(X_stream)), total=len(X_stream)):
        x_t = X_stream[t]
        y_t = y_stream[t]
        X_cand = x_t.reshape([1, -1])
        y_cand = y_t
        correct_classifications.append(clf.predict(X_cand)[0] == y_cand)
        # check whether to query the sample or not
        # call_func is used since a classifier is not needed for RandomSampler
        # and PeriodicSampler
        sampled_indices, utilities = call_func(
            query_strategy.query,
            candidates=X_cand,
            X=X_train,
            y=y_train,
            clf=clf,
            return_utilities=True,
            fit_clf=False,
        )
        # create budget_manager_param_dict for BIQF used by PALS
        budget_manager_param_dict = {"utilities": utilities}
        # update the query strategy and budget_manager to calculate the right
        # budget
        call_func(
            query_strategy.update,
            candidates=X_cand,
            queried_indices=sampled_indices,
            budget_manager_param_dict=budget_manager_param_dict,
        )
        if len(sampled_indices):
            queries_t.append(t)
        # train the classifier
        if len(sampled_indices):
            clf.partial_fit(X_cand, np.array([y_cand]))
        # add X_cand to X_train
        X_train.append(x_t)
        # add label or missing_label to y_train
        y_train_t = y_cand if len(sampled_indices) > 0 else clf.missing_label
        y_train.append(y_train_t)
    # calculate and show the average accuracy
    results[query_strategy_name] = (
        queries_t,
        np.array(correct_classifications, dtype=float),
    )
# Out:
# StreamRandomSampling
# ...
# 100%|██████████| 5000/5000 [00:02<00:00, 1787.04it/s]
# PeriodicSampler
# 100%|██████████| 5000/5000 [00:02<00:00, 2469.14it/s]
# FixedUncertainty
# 100%|██████████| 5000/5000 [00:02<00:00, 2196.78it/s]
# VariableUncertainty
# 100%|██████████| 5000/5000 [00:03<00:00, 1662.94it/s]
# RandomVariableUncertainty
# 100%|██████████| 5000/5000 [00:03<00:00, 1517.17it/s]
# Split
# 100%|██████████| 5000/5000 [00:03<00:00, 1508.62it/s]
# DBALStream
# 100%|██████████| 5000/5000 [00:04<00:00, 1038.74it/s]
# CogDQSRan
# 100%|██████████| 5000/5000 [00:04<00:00, 1186.87it/s]
# CogDQSFixUn
# 100%|██████████| 5000/5000 [00:03<00:00, 1390.46it/s]
# CogDQSVarUn
# 100%|██████████| 5000/5000 [00:04<00:00, 1211.04it/s]
# CogDQSRanVarUn
# 100%|██████████| 5000/5000 [00:04<00:00, 1159.37it/s]
# StreamProbabilisticAL
# 100%|██████████| 5000/5000 [00:07<00:00, 625.44it/s]

# %%
colormap = mpl.colormaps["tab20"]
fig, axs = plt.subplots()
for i_qs, query_strategy_name in enumerate(query_strategies):
    color = colormap(i_qs)
    queries_t, learning_curve = results[query_strategy_name]
    count = len(queries_t)
    mean_acc = np.mean(learning_curve)
    smoothed_learning_curve = gaussian_filter1d(learning_curve, 75)
    learning_curve_label = (
        f"{query_strategy_name} ({mean_acc:.4f}), {count} queries",
    )
    axs.plot(smoothed_learning_curve, label=learning_curve_label, color=color)
axs.legend(loc="upper left", bbox_to_anchor=(1, 1))
axs.set_xlabel("time (number of observed instances)")
axs.set_ylabel("smoothed prequential evaluation accuracy")
axs.set_title("Smoothed prequential evaluation accuracy over time")
plt.show(fig)

# %%
colormap = mpl.colormaps["tab20"]
fig, axs = plt.subplots()
for i_qs, query_strategy_name in enumerate(query_strategies):
    color = colormap(i_qs)
    queries_t, learning_curve = results[query_strategy_name]
    queries = np.zeros(len(learning_curve))
    queries[queries_t] = 1
    budget_curve = np.cumsum(queries) / (np.arange(len(learning_curve))+1)
    axs.plot(budget_curve, label=query_strategy_name, color=color)
axs.legend(loc="upper left", bbox_to_anchor=(1, 1))
axs.set_xlim(0,500)
axs.set_xlabel("time (number of observed samples)")
axs.set_ylabel("spent budget")
axs.set_title("Spent budget for the first 500 time steps")
plt.show(fig)
